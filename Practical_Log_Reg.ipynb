# %% [markdown]
# <a href="https://colab.research.google.com/github/Anushkacodesjava/Google--AI-Internship/blob/main/Practical_Log_Reg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_iris

X, y = load_iris(return_X_y=True)

model = LogisticRegression(max_iter=200)
model.fit(X, y)

print(model.predict(X[:5]))
# Out:
# [0 0 0 0 0]

# %%
data = {
    'Name':['Alice','Bob','Charlie','David','Alice'],
    'Age': [25,None,30,22,25],
    'City':['New York','Los Angeles',None, 'San Francisco','Chicago']
}
df = pd.DataFrame(data)

# %%
print("\nMissing values in each column : ")
print(df.isnull().sum())
# Out:
# Missing values in each column :
# Name    0
# Age     1
# City    1
# dtype: int64

# %%
df_cleaned= df.dropna()
print("\nDataFrame after dropping missing values : ")
print(df_cleaned)
# Out:
# DataFrame after dropping missing values :
#     Name   Age           City
# 0  Alice  25.0       New York
# 3  David  22.0  San Francisco
# 4  Alice  25.0        Chicago

# %%
df_filled = df.fillna({'Age':df['Age'].mean(), 'City':'Unknown'})
print("\nDataFrame after filling missing values : ")
print(df_filled)
# Out:
# DataFrame after filling missing values :
#       Name   Age           City
# 0    Alice  25.0       New York
# 1      Bob  25.5    Los Angeles
# 2  Charlie  30.0        Unknown
# 3    David  22.0  San Francisco
# 4    Alice  25.0        Chicago

# %%
df_no_duplicates = df_filled.drop_duplicates()
print("\nData Frame after removing duplicates")
print(df_no_duplicates)
# Out:
# Data Frame after removing duplicates
#       Name   Age           City
# 0    Alice  25.0       New York
# 1      Bob  25.5    Los Angeles
# 2  Charlie  30.0        Unknown
# 3    David  22.0  San Francisco
# 4    Alice  25.0        Chicago

# %%
# convert data types
df_no_duplicates['Age'] = df_no_duplicates['Age'].fillna(df_no_duplicates['Age'].mean()).astype(int)
print("\nDataFrame after converting 'Age' to integer : ")
print(df_no_duplicates)
# Out:
# DataFrame after converting 'Age' to integer :
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   25    Los Angeles
# 2  Charlie   30        Unknown
# 3    David   22  San Francisco
# 4    Alice   25        Chicago

# %%
# decision tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_iris
X,y = load_iris(return_X_y=True)
model = DecisionTreeClassifier().fit(X,y)
print(model.predict(X[:5]))
# Out:
# [0 0 0 0 0]

# %%
# Random Forest
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_iris
X,y = load_iris(return_X_y=True)
model = RandomForestClassifier(n_estimators=100)
model.fit(X,y)
print(model.score(X,y))
# Out:
# 1.0

# %%
# House Prediction

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# Example data: House sizes (in sq. ft.) and their prices (in $1000s)
house_sizes = np.array([500, 750, 1000, 1250, 1500, 1750, 2000], dtype=float)
house_prices = np.array([100, 150, 200, 250, 300, 350, 400], dtype=float)

# Build the model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(units=1, input_shape=[1])  # Linear regression
])
# Compile the model
model.compile(optimizer='sgd', loss='mean_squared_error')

# Train the model
model.fit(house_sizes, house_prices, epochs=500, verbose=0)

# Predict price for a house of 2250 sq. ft.
predicted_price = model.predict(np.array([2250.0]))
print(f"Predicted price for a 2250 sq.ft. house: ${predicted_price[0][0]*1000:.2f}")

# Optional: Plot
plt.scatter(house_sizes, house_prices, color='blue', label='Actual Prices')
plt.plot(house_sizes, model.predict(house_sizes), color='red', label='Model Prediction')
plt.xlabel('House Size (sq. ft.)')
plt.ylabel('Price ($1000s)')
plt.legend()
plt.title('House Price Prediction')
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Predicted price for a 2250 sq.ft. house: $nan
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step

# %%
# Save and Load Model

model.save('my_model.h5')
new model= tf.keras.models.load_model('my_model.h5')
# Out:
#   File "/tmp/ipykernel_1348/3128715963.py", line 4
#     new model= tf.keras.models.load_model('my_model.h5')
#         ^
# SyntaxError: invalid syntax
