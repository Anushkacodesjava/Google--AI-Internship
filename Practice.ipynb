# %% [markdown]
# <a href="https://colab.research.google.com/github/Anushkacodesjava/Google--AI-Internship/blob/main/Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
ans = np.array([[1,2],[3,4]])
print(np.mean(ans))
# Out:
# 2.5

# %%
import numpy as np
ans = np.array([[1,2],[3,4]])
print(np.mean(ans))
# Out:
# 2.5

# %%
import kagglehub
path = kagglehub.dataset_download("uciml/iris")
# Out:
# Using Colab cache for faster access to the 'iris' dataset.

# %%
import os
import pandas as pd

df = pd.read_csv(os.path.join(path,"Iris.csv"))

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
import matplotlib.pyplot as plt

x= [1,2,3,5,7]
y= [2,3,5,7,11]

plt.plot(x,y)

plt.xlabel("X- axis")
plt.ylabel("Y-axis")
plt.grid(True)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
scaler.fit(df.drop('Species',axis=1))
# Out:
# StandardScaler()

# %%
scaled_data = scaler.transform(df.drop('Species', axis=1))
print(scaled_data[:, 4])
# Out:
# [-1.31297673 -1.31297673 -1.31297673 -1.31297673 -1.31297673 -1.05003079
#  -1.18150376 -1.31297673 -1.31297673 -1.4444497  -1.31297673 -1.31297673
#  -1.4444497  -1.4444497  -1.31297673 -1.05003079 -1.05003079 -1.18150376
#  -1.18150376 -1.18150376 -1.31297673 -1.05003079 -1.31297673 -0.91855782
#  -1.31297673 -1.31297673 -1.05003079 -1.31297673 -1.31297673 -1.31297673
#  -1.31297673 -1.05003079 -1.4444497  -1.31297673 -1.4444497  -1.31297673
#  -1.31297673 -1.4444497  -1.31297673 -1.31297673 -1.18150376 -1.18150376
#  -1.31297673 -0.78708485 -1.05003079 -1.18150376 -1.31297673 -1.31297673
#  -1.31297673 -1.31297673  0.26469891  0.39617188  0.39617188  0.13322594
#   0.39617188  0.13322594  0.52764485 -0.26119297  0.13322594  0.26469891
#  -0.26119297  0.39617188 -0.26119297  0.26469891  0.13322594  0.26469891
#   0.39617188 -0.26119297  0.39617188 -0.12972     0.79059079  0.13322594
#   0.39617188  0.00175297  0.13322594  0.26469891  0.26469891  0.65911782
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.datasets import load_diabetes
X,y= load_diabetes(return_X_y= True)
model= LinearRegression().fit(X,y)
print(model.coef_)
# Out:
# [ -10.0098663  -239.81564367  519.84592005  324.3846455  -792.17563855
#   476.73902101  101.04326794  177.06323767  751.27369956   67.62669218]
